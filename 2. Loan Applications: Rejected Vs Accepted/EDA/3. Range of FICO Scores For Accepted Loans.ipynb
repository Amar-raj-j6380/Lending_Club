# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
sns.set()

# %%
pd.set_option("display.max_columns", 200)
pd.set_option("display.max_row", 160)
pd.set_option('max_colwidth', 200)

# %%
a = pd.read_csv('../Data/accepted.csv')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (0,19,49,59,118,129,130,131,134,135,136,139,145,146,147) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
a = a.assign(FICO = (a['fico_range_low'] + a['fico_range_high'])/2)

# %%
plt.figure(figsize=(8,4))
plt.style.use('default')
plt.style.use('ggplot')

sns.displot(data=a, x='FICO', kind='hist', bins=15, color = 'blue', aspect=1.5)

plt.title('FICO Scores For Accepted Loans', fontsize=16, color='black')
plt.xlabel('FICO Score', fontsize=14, color='black')
plt.ylabel('Loan Count', fontsize=14, color='black')
#plt.legend(fontsize=12)

plt.tight_layout()
plt.show();

# %%
a[['FICO']].describe()
# Out:
#                FICO
# count  2.260668e+06
# mean   7.005883e+02
# std    3.301081e+01
# min    6.120000e+02
# 25%    6.770000e+02
# 50%    6.920000e+02
# 75%    7.170000e+02
# max    8.475000e+02

# %%
a[a.FICO==660]
# Out:
# Empty DataFrame
# Columns: [id, member_id, loan_amnt, funded_amnt, funded_amnt_inv, term, int_rate, installment, grade, sub_grade, emp_title, emp_length, home_ownership, annual_inc, verification_status, issue_d, loan_status, pymnt_plan, url, desc, purpose, title, zip_code, addr_state, dti, delinq_2yrs, earliest_cr_line, fico_range_low, fico_range_high, inq_last_6mths, mths_since_last_delinq, mths_since_last_record, open_acc, pub_rec, revol_bal, revol_util, total_acc, initial_list_status, out_prncp, out_prncp_inv, total_pymnt, total_pymnt_inv, total_rec_prncp, total_rec_int, total_rec_late_fee, recoveries, collection_recovery_fee, last_pymnt_d, last_pymnt_amnt, next_pymnt_d, last_credit_pull_d, last_fico_range_high, last_fico_range_low, collections_12_mths_ex_med, mths_since_last_major_derog, policy_code, application_type, annual_inc_joint, dti_joint, verification_status_joint, acc_now_delinq, tot_coll_amt, tot_cur_bal, open_acc_6m, open_act_il, open_il_12m, open_il_24m, mths_since_rcnt_il, total_bal_il, il_util, open_rv_12m, open_rv_24m, max_bal_bc, all_util, total_rev_hi_lim, inq_fi, total_cu_tl, inq_last_12m, acc_open_past_24mths, avg_cur_bal, bc_open_to_buy, bc_util, chargeoff_within_12_mths, delinq_amnt, mo_sin_old_il_acct, mo_sin_old_rev_tl_op, mo_sin_rcnt_rev_tl_op, mo_sin_rcnt_tl, mort_acc, mths_since_recent_bc, mths_since_recent_bc_dlq, mths_since_recent_inq, mths_since_recent_revol_delinq, num_accts_ever_120_pd, num_actv_bc_tl, num_actv_rev_tl, num_bc_sats, num_bc_tl, num_il_tl, num_op_rev_tl, ...]
# Index: []

# %%
a[['fico_range_low']].describe()
# Out:
#        fico_range_low
# count    2.260668e+06
# mean     6.985882e+02
# std      3.301038e+01
# min      6.100000e+02
# 25%      6.750000e+02
# 50%      6.900000e+02
# 75%      7.150000e+02
# max      8.450000e+02

# %%
a[a.fico_range_low==660]
# Out:
#                id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 31       68341789        NaN    24250.0      24250.0          24250.0
# 83       68376217        NaN    23100.0      23100.0          23100.0
# 84       68526942        NaN    27300.0      27300.0          27300.0
# 109      68496036        NaN    10500.0      10500.0          10500.0
# 121      68546562        NaN    24000.0      24000.0          24000.0
# ...           ...        ...        ...          ...              ...
# 2260604  90165728        NaN    12000.0      12000.0          12000.0
# 2260639  90094364        NaN     4500.0       4500.0           4500.0
# 2260662  89848546        NaN    24000.0      24000.0          24000.0
# 2260697  88224441        NaN    24000.0      24000.0          24000.0
# 2260698  88215728        NaN    14000.0      14000.0          14000.0
#
#                term  int_rate  installment grade sub_grade  \
# 31        60 months     24.24       701.01     F        F3
# 83        60 months     20.50       618.46     E        E4
# 84        36 months     17.27       977.00     D        D3
# 109       36 months     15.77       367.96     D        D1
# 121       36 months      9.17       765.10     B        B2
# ...             ...       ...          ...   ...       ...
# 2260604   60 months     13.49       276.06     C        C2
# 2260639   36 months     14.49       154.88     C        C4
# 2260662   60 months     13.99       558.32     C        C3
# 2260697   60 months     14.49       564.56     C        C4
# 2260698   60 months     14.49       329.33     C        C4
#
#                            emp_title emp_length home_ownership  annual_inc  \
# 31                   hvac technician    4 years       MORTGAGE     75000.0
# 83          Regional Sales Direcdtor    2 years            OWN    110000.0
# 84                        groundsman  10+ years       MORTGAGE     65000.0
# 109                Software Engineer    3 years           RENT     70100.0
# 121               Accounting Manager  10+ years       MORTGAGE     75000.0
# ...                              ...        ...            ...         ...
# 2260604             retail associate  10+ years       MORTGAGE     85000.0
# 2260639    IT Solutions Architect II  10+ years       MORTGAGE    120000.0
# 2260662                     OR TECH     9 years            OWN     70000.0
# 2260697              Program Manager    6 years           RENT    110000.0
# 2260698  Customer Service Technician  10+ years       MORTGAGE     95000.0
#
#         verification_status   issue_d  loan_status pymnt_plan  \
# 31             Not Verified  Dec-2015  Charged Off          n
# 83             Not Verified  Dec-2015  Charged Off          n
# 84             Not Verified  Dec-2015  Charged Off          n
# 109         Source Verified  Dec-2015   Fully Paid          n
# 121         Source Verified  Dec-2015   Fully Paid          n
# ...                     ...       ...          ...        ...
# 2260604        Not Verified  Oct-2016   Fully Paid          n
# 2260639            Verified  Oct-2016   Fully Paid          n
# 2260662        Not Verified  Oct-2016      Current          n
# 2260697        Not Verified  Oct-2016  Charged Off          n
# 2260698            Verified  Oct-2016      Current          n
#
#                                                                        url  \
# 31       https://lendingclub.com/browse/loanDetail.action?loan_id=68341789
# 83       https://lendingclub.com/browse/loanDetail.action?loan_id=68376217
# 84       https://lendingclub.com/browse/loanDetail.action?loan_id=68526942
# 109      https://lendingclub.com/browse/loanDetail.action?loan_id=68496036
# 121      https://lendingclub.com/browse/loanDetail.action?loan_id=68546562
# ...                                                                    ...
# 2260604  https://lendingclub.com/browse/loanDetail.action?loan_id=90165728
# 2260639  https://lendingclub.com/browse/loanDetail.action?loan_id=90094364
# 2260662  https://lendingclub.com/browse/loanDetail.action?loan_id=89848546
# 2260697  https://lendingclub.com/browse/loanDetail.action?loan_id=88224441
# 2260698  https://lendingclub.com/browse/loanDetail.action?loan_id=88215728
#
#         desc             purpose                    title zip_code addr_state  \
# 31       NaN  debt_consolidation                      NaN    114xx         NY
# 83       NaN                 car            Car financing    197xx         DE
# 84       NaN    home_improvement         Home improvement    117xx         NY
# 109      NaN         credit_card  Credit card refinancing    661xx         KS
# 121      NaN  debt_consolidation       Debt consolidation    029xx         RI
# ...      ...                 ...                      ...      ...        ...
# 2260604  NaN  debt_consolidation       Debt consolidation    109xx         NY
# 2260639  NaN  debt_consolidation       Debt consolidation    750xx         TX
# 2260662  NaN  debt_consolidation       Debt consolidation    071xx         NJ
# 2260697  NaN  debt_consolidation       Debt consolidation    334xx         FL
# 2260698  NaN  debt_consolidation                      NaN    770xx         TX
#
#            dti  delinq_2yrs earliest_cr_line  fico_range_low  fico_range_high  \
# 31       20.84          0.0         Apr-2007           660.0            664.0
# 83       20.43          0.0         Aug-1986           660.0            664.0
# 84       25.63          0.0         Nov-2002           660.0            664.0
# 109       8.51          0.0         Aug-2008           660.0            664.0
# 121      10.11          0.0         May-1985           660.0            664.0
# ...        ...          ...              ...             ...              ...
# 2260604   8.91          0.0         Apr-2001           660.0            664.0
# 2260639  17.49          0.0         Jun-2001           660.0            664.0
# 2260662  13.94          0.0         Sep-2007           660.0            664.0
# 2260697  18.30          0.0         Jul-1999           660.0            664.0
# 2260698  23.36          0.0         Jun-1996           660.0            664.0
#
#          inq_last_6mths  mths_since_last_delinq  mths_since_last_record  \
# 31                  0.0                     NaN                     NaN
# 83                  0.0                    47.0                     NaN
# 84                  0.0                     NaN                     NaN
# 109                 0.0                    35.0                     NaN
# 121                 3.0                     NaN                    47.0
# ...                 ...                     ...                     ...
# 2260604             0.0                     NaN                    77.0
# 2260639             0.0                    80.0                     NaN
# 2260662             1.0                     NaN                     NaN
# 2260697             0.0                    67.0                    72.0
# 2260698             1.0                    37.0                     NaN
#
#          open_acc  pub_rec  revol_bal  revol_util  total_acc  \
# 31           18.0      0.0    24799.0        65.3       21.0
# 83           11.0      0.0    20594.0        94.9       24.0
# 84           14.0      0.0    31035.0        83.0       38.0
# 109           5.0      0.0     8280.0        77.4       10.0
# 121          14.0      1.0    11763.0        39.5       25.0
# ...           ...      ...        ...         ...        ...
# 2260604      12.0      1.0    10109.0        46.6       24.0
# 2260639      13.0      0.0    53599.0       100.0       20.0
# 2260662      20.0      0.0    34824.0        43.3       42.0
# 2260697      10.0      1.0    17641.0        68.1       31.0
# 2260698       8.0      0.0     7662.0        54.0       22.0
#
#         initial_list_status  out_prncp  out_prncp_inv   total_pymnt  \
# 31                        w       0.00           0.00   4124.420000
# 83                        w       0.00           0.00   5305.120000
# 84                        w       0.00           0.00   8727.520000
# 109                       w       0.00           0.00  13048.516847
# 121                       w       0.00           0.00  27505.011936
# ...                     ...        ...            ...           ...
# 2260604                   f       0.00           0.00  13290.058098
# 2260639                   f       0.00           0.00   5074.673110
# 2260662                   f   14327.40       14327.40  16244.650000
# 2260697                   f       0.00           0.00   6755.400000
# 2260698                   w    8456.12        8456.12   9621.250000
#
#          total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 31               4124.42          1332.69        2791.73                0.00
# 83               5305.12          1158.07        1868.46                0.00
# 84               8727.52          5569.98        3157.54                0.00
# 109             13048.52         10500.00        2548.52                0.00
# 121             27505.01         24000.00        3505.01                0.00
# ...                  ...              ...            ...                 ...
# 2260604         13290.06         12000.00        1290.06                0.00
# 2260639          5074.67          4500.00         574.67                0.00
# 2260662         16244.65          9672.60        6572.05                0.00
# 2260697          6755.40          3521.91        3233.49                0.00
# 2260698          9621.25          5543.88        4027.96               49.41
#
#          recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 31             0.00                   0.0000     Jul-2016           701.01
# 83          2278.59                 410.1462     Jun-2016           618.46
# 84             0.00                   0.0000     Oct-2016           977.00
# 109            0.00                   0.0000     May-2018          3036.60
# 121            0.00                   0.0000     Jan-2019           732.08
# ...             ...                      ...          ...              ...
# 2260604        0.00                   0.0000     Aug-2017         10814.51
# 2260639        0.00                   0.0000     Oct-2017          3374.61
# 2260662        0.00                   0.0000     Mar-2019           558.32
# 2260697        0.00                   0.0000     Oct-2017           564.56
# 2260698        0.00                   0.0000     Mar-2019           329.33
#
#         next_pymnt_d last_credit_pull_d  last_fico_range_high  \
# 31               NaN           Mar-2018                 499.0
# 83               NaN           Dec-2016                 584.0
# 84               NaN           May-2018                 524.0
# 109              NaN           May-2018                 674.0
# 121              NaN           Jan-2019                 704.0
# ...              ...                ...                   ...
# 2260604          NaN           Aug-2017                 679.0
# 2260639          NaN           Oct-2017                 594.0
# 2260662     Apr-2019           Mar-2019                 694.0
# 2260697          NaN           Mar-2019                 594.0
# 2260698     Apr-2019           Mar-2019                 669.0
#
#          last_fico_range_low  collections_12_mths_ex_med  \
# 31                       0.0                         0.0
# 83                     580.0                         0.0
# 84                     520.0                         0.0
# 109                    670.0                         0.0
# 121                    700.0                         0.0
# ...                      ...                         ...
# 2260604                675.0                         0.0
# 2260639                590.0                         0.0
# 2260662                690.0                         1.0
# 2260697                590.0                         0.0
# 2260698                665.0                         0.0
#
#          mths_since_last_major_derog  policy_code application_type  \
# 31                               NaN          1.0       Individual
# 83                              47.0          1.0       Individual
# 84                               NaN          1.0       Individual
# 109                             35.0          1.0       Individual
# 121                              NaN          1.0       Individual
# ...                              ...          ...              ...
# 2260604                          NaN          1.0       Individual
# 2260639                          NaN          1.0       Individual
# 2260662                          NaN          1.0       Individual
# 2260697                         67.0          1.0       Individual
# 2260698                         37.0          1.0       Individual
#
#          annual_inc_joint  dti_joint verification_status_joint  \
# 31                    NaN        NaN                       NaN
# 83                    NaN        NaN                       NaN
# 84                    NaN        NaN                       NaN
# 109                   NaN        NaN                       NaN
# 121                   NaN        NaN                       NaN
# ...                   ...        ...                       ...
# 2260604               NaN        NaN                       NaN
# 2260639               NaN        NaN                       NaN
# 2260662               NaN        NaN                       NaN
# 2260697               NaN        NaN                       NaN
# 2260698               NaN        NaN                       NaN
#
#          acc_now_delinq  tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  \
# 31                  0.0           0.0     320098.0          2.0          1.0
# 83                  0.0        1105.0      55048.0          1.0          3.0
# 84                  0.0           0.0     238105.0          0.0          1.0
# 109                 0.0           0.0      26327.0          1.0          1.0
# 121                 0.0           0.0      20031.0          2.0          1.0
# ...                 ...           ...          ...          ...          ...
# 2260604             0.0           0.0     158493.0          1.0          1.0
# 2260639             0.0           0.0     182132.0          0.0          1.0
# 2260662             0.0         251.0     212878.0          0.0          2.0
# 2260697             0.0           0.0      62426.0          0.0          2.0
# 2260698             0.0           0.0     143066.0          0.0          1.0
#
#          open_il_12m  open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  \
# 31               0.0          1.0                14.0       13676.0     75.0
# 83               0.0          0.0                25.0       34454.0     43.0
# 84               0.0          2.0                16.0       29947.0     81.0
# 109              1.0          1.0                 9.0       18047.0     84.0
# 121              0.0          1.0                16.0        8268.0     64.0
# ...              ...          ...                 ...           ...      ...
# 2260604          1.0          2.0                 5.0       22752.0     95.0
# 2260639          0.0          1.0                14.0        6960.0     45.0
# 2260662          0.0          0.0                30.0        3217.0     45.0
# 2260697          0.0          2.0                20.0       44785.0     78.0
# 2260698          1.0          2.0                 7.0       32071.0     94.0
#
#          open_rv_12m  open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  \
# 31               2.0         10.0      3138.0      61.0           38000.0
# 83               3.0          5.0      4871.0      54.0           21700.0
# 84               2.0          3.0      9413.0      82.0           37400.0
# 109              2.0          2.0      5706.0      82.0           10700.0
# 121              2.0          5.0      5200.0      47.0           29800.0
# ...              ...          ...         ...       ...               ...
# 2260604          1.0          2.0      5976.0      72.0           21700.0
# 2260639          1.0          1.0      7659.0      88.0           53600.0
# 2260662          0.0          0.0     14712.0      43.0           80400.0
# 2260697          1.0          5.0      6172.0      73.0           25900.0
# 2260698          0.0          1.0      4093.0      84.0           14200.0
#
#          inq_fi  total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  \
# 31          1.0          1.0           3.0                  13.0      17783.0
# 83          3.0          0.0           9.0                   5.0       5505.0
# 84          2.0          2.0           3.0                   7.0      18316.0
# 109         2.0          0.0           6.0                   3.0       5265.0
# 121         1.0          0.0           3.0                   6.0       1541.0
# ...         ...          ...           ...                   ...          ...
# 2260604     1.0          2.0           2.0                   5.0      14408.0
# 2260639     0.0          2.0           2.0                   2.0      14010.0
# 2260662     2.0          1.0           3.0                   1.0      10644.0
# 2260697     0.0          0.0           1.0                   7.0       6243.0
# 2260698     3.0          1.0           2.0                   3.0      17883.0
#
#          bc_open_to_buy  bc_util  chargeoff_within_12_mths  delinq_amnt  \
# 31               9044.0     68.9                       0.0          0.0
# 83               1106.0     94.9                       0.0          0.0
# 84               3924.0     87.7                       0.0          0.0
# 109              2420.0     77.4                       0.0          0.0
# 121              9037.0     55.0                       0.0          0.0
# ...                 ...      ...                       ...          ...
# 2260604          8091.0     55.5                       0.0          0.0
# 2260639             0.0    101.1                       0.0          0.0
# 2260662         28382.0     51.8                       0.0          0.0
# 2260697          4660.0     77.5                       0.0          0.0
# 2260698          1838.0     80.7                       0.0          0.0
#
#          mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  \
# 31                     93.0                 104.0                    2.0
# 83                    159.0                 352.0                    3.0
# 84                    150.0                 157.0                   11.0
# 109                     9.0                  88.0                    6.0
# 121                   136.0                 367.0                    1.0
# ...                     ...                   ...                    ...
# 2260604               127.0                 185.0                    9.0
# 2260639               183.0                 110.0                    8.0
# 2260662               103.0                 108.0                   25.0
# 2260697               132.0                 206.0                    9.0
# 2260698               149.0                 243.0                   22.0
#
#          mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  \
# 31                  2.0       2.0                   2.0
# 83                  3.0       2.0                   3.0
# 84                  9.0       2.0                  17.0
# 109                 6.0       0.0                   6.0
# 121                 1.0       3.0                  14.0
# ...                 ...       ...                   ...
# 2260604             5.0       2.0                  17.0
# 2260639             8.0       3.0                  29.0
# 2260662            10.0       1.0                  25.0
# 2260697             9.0       2.0                   9.0
# 2260698             7.0       1.0                  75.0
#
#          mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 31                            NaN                    7.0
# 83                           47.0                    0.0
# 84                            NaN                    8.0
# 109                          35.0                    4.0
# 121                           NaN                    1.0
# ...                           ...                    ...
# 2260604                       NaN                    9.0
# 2260639                      80.0                    8.0
# 2260662                       NaN                    1.0
# 2260697                       NaN                    9.0
# 2260698                      39.0                    6.0
#
#          mths_since_recent_revol_delinq  num_accts_ever_120_pd  \
# 31                                  NaN                    0.0
# 83                                 47.0                    1.0
# 84                                  NaN                    0.0
# 109                                35.0                    2.0
# 121                                 NaN                    0.0
# ...                                 ...                    ...
# 2260604                             NaN                    0.0
# 2260639                            80.0                    0.0
# 2260662                             NaN                    0.0
# 2260697                             NaN                    1.0
# 2260698                            37.0                    4.0
#
#          num_actv_bc_tl  num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  \
# 31                 10.0             12.0         11.0       12.0        2.0
# 83                  5.0              5.0          8.0       11.0       10.0
# 84                  7.0              9.0          7.0       17.0        5.0
# 109                 3.0              3.0          4.0        7.0        1.0
# 121                 4.0              5.0          5.0       11.0        3.0
# ...                 ...              ...          ...        ...        ...
# 2260604             4.0              4.0          7.0       16.0        3.0
# 2260639             4.0             11.0          4.0        5.0        5.0
# 2260662             9.0             13.0          9.0       16.0       12.0
# 2260697             5.0              7.0          5.0       15.0        4.0
# 2260698             3.0              3.0          4.0       12.0        3.0
#
#          num_op_rev_tl  num_rev_accts  num_rev_tl_bal_gt_0  num_sats  \
# 31                15.0           16.0                 12.0      18.0
# 83                 8.0           12.0                  6.0      11.0
# 84                11.0           31.0                  9.0      14.0
# 109                4.0            9.0                  3.0       5.0
# 121               13.0           19.0                  5.0      13.0
# ...                ...            ...                  ...       ...
# 2260604           10.0           19.0                  4.0      11.0
# 2260639           11.0           12.0                 11.0      13.0
# 2260662           17.0           29.0                 13.0      20.0
# 2260697            8.0           24.0                  7.0      10.0
# 2260698            5.0           17.0                  3.0       8.0
#
#          num_tl_120dpd_2m  num_tl_30dpd  num_tl_90g_dpd_24m  \
# 31                    0.0           0.0                 0.0
# 83                    0.0           0.0                 0.0
# 84                    0.0           0.0                 0.0
# 109                   0.0           0.0                 0.0
# 121                   0.0           0.0                 0.0
# ...                   ...           ...                 ...
# 2260604               0.0           0.0                 0.0
# 2260639               0.0           0.0                 0.0
# 2260662               0.0           0.0                 0.0
# 2260697               0.0           0.0                 0.0
# 2260698               0.0           0.0                 0.0
#
#          num_tl_op_past_12m  pct_tl_nvr_dlq  percent_bc_gt_75  \
# 31                      3.0           100.0              63.6
# 83                      3.0            87.5              85.7
# 84                      3.0           100.0              85.7
# 109                     3.0            80.0              50.0
# 121                     2.0           100.0              40.0
# ...                     ...             ...               ...
# 2260604                 3.0           100.0              42.9
# 2260639                 1.0            95.0             100.0
# 2260662                 1.0           100.0              22.2
# 2260697                 1.0            96.2              40.0
# 2260698                 1.0            81.8              50.0
#
#          pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  total_bal_ex_mort  \
# 31                        0.0        0.0         344960.0            38475.0
# 83                        0.0        0.0         102524.0            55048.0
# 84                        0.0        0.0         253900.0            60982.0
# 109                       0.0        0.0          32280.0            26327.0
# 121                       1.0        0.0          42800.0            20031.0
# ...                       ...        ...              ...                ...
# 2260604                   1.0        0.0         172985.0            32861.0
# 2260639                   0.0        0.0         212885.0            60559.0
# 2260662                   0.0        0.0         267290.0            38041.0
# 2260697                   1.0        0.0          84664.0            62426.0
# 2260698                   0.0        0.0         163804.0            44215.0
#
#          total_bc_limit  total_il_high_credit_limit  revol_bal_joint  \
# 31              29100.0                     18300.0              NaN
# 83              21700.0                     80824.0              NaN
# 84              32000.0                     37192.0              NaN
# 109             10700.0                     21580.0              NaN
# 121             20100.0                     13000.0              NaN
# ...                 ...                         ...              ...
# 2260604         18200.0                     23904.0              NaN
# 2260639         13300.0                     15423.0              NaN
# 2260662         58900.0                      7205.0              NaN
# 2260697         20700.0                     58764.0              NaN
# 2260698          9500.0                     34169.0              NaN
#
#          sec_app_fico_range_low  sec_app_fico_range_high  \
# 31                          NaN                      NaN
# 83                          NaN                      NaN
# 84                          NaN                      NaN
# 109                         NaN                      NaN
# 121                         NaN                      NaN
# ...                         ...                      ...
# 2260604                     NaN                      NaN
# 2260639                     NaN                      NaN
# 2260662                     NaN                      NaN
# 2260697                     NaN                      NaN
# 2260698                     NaN                      NaN
#
#         sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# 31                           NaN                     NaN               NaN
# 83                           NaN                     NaN               NaN
# 84                           NaN                     NaN               NaN
# 109                          NaN                     NaN               NaN
# 121                          NaN                     NaN               NaN
# ...                          ...                     ...               ...
# 2260604                      NaN                     NaN               NaN
# 2260639                      NaN                     NaN               NaN
# 2260662                      NaN                     NaN               NaN
# 2260697                      NaN                     NaN               NaN
# 2260698                      NaN                     NaN               NaN
#
#          sec_app_open_acc  sec_app_revol_util  sec_app_open_act_il  \
# 31                    NaN                 NaN                  NaN
# 83                    NaN                 NaN                  NaN
# 84                    NaN                 NaN                  NaN
# 109                   NaN                 NaN                  NaN
# 121                   NaN                 NaN                  NaN
# ...                   ...                 ...                  ...
# 2260604               NaN                 NaN                  NaN
# 2260639               NaN                 NaN                  NaN
# 2260662               NaN                 NaN                  NaN
# 2260697               NaN                 NaN                  NaN
# 2260698               NaN                 NaN                  NaN
#
#          sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# 31                         NaN                               NaN
# 83                         NaN                               NaN
# 84                         NaN                               NaN
# 109                        NaN                               NaN
# 121                        NaN                               NaN
# ...                        ...                               ...
# 2260604                    NaN                               NaN
# 2260639                    NaN                               NaN
# 2260662                    NaN                               NaN
# 2260697                    NaN                               NaN
# 2260698                    NaN                               NaN
#
#          sec_app_collections_12_mths_ex_med  \
# 31                                      NaN
# 83                                      NaN
# 84                                      NaN
# 109                                     NaN
# 121                                     NaN
# ...                                     ...
# 2260604                                 NaN
# 2260639                                 NaN
# 2260662                                 NaN
# 2260697                                 NaN
# 2260698                                 NaN
#
#          sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 31                                       NaN             N           NaN
# 83                                       NaN             N           NaN
# 84                                       NaN             N           NaN
# 109                                      NaN             N           NaN
# 121                                      NaN             N           NaN
# ...                                      ...           ...           ...
# 2260604                                  NaN             N           NaN
# 2260639                                  NaN             N           NaN
# 2260662                                  NaN             N           NaN
# 2260697                                  NaN             N           NaN
# 2260698                                  NaN             N           NaN
#
#         hardship_reason hardship_status  deferral_term  hardship_amount  \
# 31                  NaN             NaN            NaN              NaN
# 83                  NaN             NaN            NaN              NaN
# 84                  NaN             NaN            NaN              NaN
# 109                 NaN             NaN            NaN              NaN
# 121                 NaN             NaN            NaN              NaN
# ...                 ...             ...            ...              ...
# 2260604             NaN             NaN            NaN              NaN
# 2260639             NaN             NaN            NaN              NaN
# 2260662             NaN             NaN            NaN              NaN
# 2260697             NaN             NaN            NaN              NaN
# 2260698             NaN             NaN            NaN              NaN
#
#         hardship_start_date hardship_end_date payment_plan_start_date  \
# 31                      NaN               NaN                     NaN
# 83                      NaN               NaN                     NaN
# 84                      NaN               NaN                     NaN
# 109                     NaN               NaN                     NaN
# 121                     NaN               NaN                     NaN
# ...                     ...               ...                     ...
# 2260604                 NaN               NaN                     NaN
# 2260639                 NaN               NaN                     NaN
# 2260662                 NaN               NaN                     NaN
# 2260697                 NaN               NaN                     NaN
# 2260698                 NaN               NaN                     NaN
#
#          hardship_length  hardship_dpd hardship_loan_status  \
# 31                   NaN           NaN                  NaN
# 83                   NaN           NaN                  NaN
# 84                   NaN           NaN                  NaN
# 109                  NaN           NaN                  NaN
# 121                  NaN           NaN                  NaN
# ...                  ...           ...                  ...
# 2260604              NaN           NaN                  NaN
# 2260639              NaN           NaN                  NaN
# 2260662              NaN           NaN                  NaN
# 2260697              NaN           NaN                  NaN
# 2260698              NaN           NaN                  NaN
#
#          orig_projected_additional_accrued_interest  \
# 31                                              NaN
# 83                                              NaN
# 84                                              NaN
# 109                                             NaN
# 121                                             NaN
# ...                                             ...
# 2260604                                         NaN
# 2260639                                         NaN
# 2260662                                         NaN
# 2260697                                         NaN
# 2260698                                         NaN
#
#          hardship_payoff_balance_amount  hardship_last_payment_amount  \
# 31                                  NaN                           NaN
# 83                                  NaN                           NaN
# 84                                  NaN                           NaN
# 109                                 NaN                           NaN
# 121                                 NaN                           NaN
# ...                                 ...                           ...
# 2260604                             NaN                           NaN
# 2260639                             NaN                           NaN
# 2260662                             NaN                           NaN
# 2260697                             NaN                           NaN
# 2260698                             NaN                           NaN
#
#         disbursement_method debt_settlement_flag debt_settlement_flag_date  \
# 31                     Cash                    N                       NaN
# 83                     Cash                    N                       NaN
# 84                     Cash                    N                       NaN
# 109                    Cash                    N                       NaN
# 121                    Cash                    N                       NaN
# ...                     ...                  ...                       ...
# 2260604                Cash                    N                       NaN
# 2260639                Cash                    N                       NaN
# 2260662                Cash                    N                       NaN
# 2260697                Cash                    Y                  Mar-2019
# 2260698                Cash                    N                       NaN
#
#         settlement_status settlement_date  settlement_amount  \
# 31                    NaN             NaN                NaN
# 83                    NaN             NaN                NaN
# 84                    NaN             NaN                NaN
# 109                   NaN             NaN                NaN
# 121                   NaN             NaN                NaN
# ...                   ...             ...                ...
# 2260604               NaN             NaN                NaN
# 2260639               NaN             NaN                NaN
# 2260662               NaN             NaN                NaN
# 2260697            ACTIVE        Mar-2019            10000.0
# 2260698               NaN             NaN                NaN
#
#          settlement_percentage  settlement_term   FICO
# 31                         NaN              NaN  662.0
# 83                         NaN              NaN  662.0
# 84                         NaN              NaN  662.0
# 109                        NaN              NaN  662.0
# 121                        NaN              NaN  662.0
# ...                        ...              ...    ...
# 2260604                    NaN              NaN  662.0
# 2260639                    NaN              NaN  662.0
# 2260662                    NaN              NaN  662.0
# 2260697                  44.82              1.0  662.0
# 2260698                    NaN              NaN  662.0
#
# [186580 rows x 152 columns]

# %%
plt.figure(figsize=(8,4))
plt.style.use('default')
plt.style.use('ggplot')

sns.displot(data=a, x='fico_range_low', kind='hist', bins=15, color = 'blue', aspect=1.5)

plt.title('FICO Scores For Accepted Loans', fontsize=16, color='black')
plt.xlabel('FICO Score', fontsize=14, color='black')
plt.ylabel('Loan Count', fontsize=14, color='black')
#plt.legend(fontsize=12)

plt.tight_layout()
plt.show();

# %%
a = a[(a.fico_range_low>=660)&(a.fico_range_low<=840)]

# %%
a.shape
# Out:
# (2259738, 152)

# %%
a[['fico_range_low', 'FICO']].describe()
# Out:
#        fico_range_low          FICO
# count    2.259738e+06  2.259738e+06
# mean     6.985707e+02  7.005707e+02
# std      3.294495e+01  3.294495e+01
# min      6.600000e+02  6.620000e+02
# 25%      6.750000e+02  6.770000e+02
# 50%      6.900000e+02  6.920000e+02
# 75%      7.150000e+02  7.170000e+02
# max      8.400000e+02  8.420000e+02

# %%
plt.figure(figsize=(10,6))
plt.style.use('default')
plt.style.use('ggplot')

p = sns.displot(data=a, x='fico_range_low', kind='hist', color='blue',
                bins=18, aspect=1.75)

p.set(xticks=np.arange(620,850,20))

plt.title('FICO Scores for Accepted Loans', fontsize=22, color='black')
plt.xlabel('FICO Score', fontsize=18, color='black')
plt.ylabel('Loan Count', fontsize=18, color='black')

#plt.legend(loc='center right', fontsize=15)

#handles, labels = p.get_legend_handles_labels()
#p.legend(handles=handles[1:], labels=labels[1:])

#sns.move_legend(obj=p, loc='center right', fontsize=15, title_fontsize=15)

plt.tight_layout()
plt.show();

# %%
plt.figure(figsize=(8,4))
plt.style.use('default')
plt.style.use('ggplot')

sns.displot(data=a, x='FICO', kind='kde', fill=True,
            color = 'blue')
#, height=5, aspect=1.5)


plt.title('Distribution Of FICO Scores For Accepted Loans', fontsize=16, color='black')
plt.xlabel('Risk or FICO Score', fontsize=14, color='black')
plt.ylabel('Density', fontsize=14, color='black')
plt.legend(fontsize=12)

plt.tight_layout()
plt.show();
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(8,4))
plt.style.use('default')
plt.style.use('ggplot')

sns.displot(data=a, x='FICO', kind='hist', bins=15, color = 'blue', aspect=1.5)


plt.title('FICO Scores For Accepted Loans', fontsize=16, color='black')
plt.xlabel('Risk or FICO Score', fontsize=14, color='black')
plt.ylabel('Count', fontsize=14, color='black')
#plt.legend(fontsize=12)

plt.tight_layout()
plt.show();

# %%
plt.figure(figsize=(8,4))
plt.style.use('default')
plt.style.use('ggplot')

sns.displot(data=a, x='FICO', kde=True,
            color = 'blue')
#, height=5, aspect=1.5)


plt.title('Distribution Of FICO Scores For Accepted Loans', fontsize=16, color='black')
plt.xlabel('Risk or FICO Score', fontsize=14, color='black')
plt.ylabel('Density', fontsize=14, color='black')
plt.legend(fontsize=12)

plt.tight_layout()
plt.show();
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(8,4))
plt.style.use('default')
plt.style.use('ggplot')

sns.displot(data=a, x='FICO', color = 'blue')
#, height=5, aspect=1.5)


plt.title('Distribution Of FICO Scores For Accepted Loans', fontsize=16, color='black')
plt.xlabel('Risk or FICO Score', fontsize=14, color='black')
plt.ylabel('Density', fontsize=14, color='black')
plt.legend(fontsize=12)

plt.tight_layout()
plt.show();
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(8,4))
plt.style.use('default')
plt.style.use('ggplot')

sns.displot(data=a, x='FICO', kind='ecdf',
            color = 'blue')
#, height=5, aspect=1.5)


plt.title('Distribution Of FICO Scores For Accepted Loans', fontsize=16, color='black')
plt.xlabel('Risk or FICO Score', fontsize=14, color='black')
plt.ylabel('Density', fontsize=14, color='black')
plt.legend(fontsize=12)

plt.tight_layout()
plt.show();
# Out:
# No handles with labels found to put in legend.
