# %%
import pandas as pd

# %%
data = pd.read_csv('../../../Data/20%_Loans_12_feat_scaled_verify_or_not.csv')

# %%
data.head(5)
# Out:
#    loan_amnt  int_rate  installment  annual_inc       dti  fico_range_low  \
# 0  -0.813096 -0.398686    -0.934226    0.562180  0.284043        0.654268
# 1   0.638440  0.261028     0.470223    0.029274 -0.010299       -1.040687
# 2  -0.241914 -0.148068    -0.394106   -0.513897  0.900017        3.559904
# 3   0.517915 -1.117370     0.188206    0.662975 -0.036939       -1.040687
# 4   1.765084 -1.117370     1.276645    0.844032  0.954597        0.896404
#
#     pub_rec      term  verification_status     grade  emp_length       ANY  \
# 0 -0.379653  0.731341            -0.379497  0.845577   -0.664012 -0.017317
# 1 -0.379653  0.731341             2.635065  0.845577   -0.409357 -0.017317
# 2 -0.379653  0.731341             2.635065  0.845577    1.118570 -0.017317
# 3 -0.379653  0.731341             2.635065 -0.408699   -0.918667 -0.017317
# 4 -0.379653  0.731341            -0.379497 -0.408699    0.609261 -0.017317
#
#    MORTGAGE      NONE     OTHER       OWN      RENT  loan_status_bin
# ...

# %%
data.shape
# Out:
# (110074, 18)

# %%
data.verification_status.value_counts()
# Out:
# -0.379497    96217
#  2.635065    13857
# Name: verification_status, dtype: int64

# %%
#few = data.groupby('loan_status_bin', group_keys=False).apply(lambda x: x.sample(frac=0.1))

# %%
#few.shape

# %%
from pycaret.classification import *

# %%
experiment = setup(data = data, target = 'loan_status_bin')
# Out:
# <style type="text/css">
# #T_4e844_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4e844_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e844_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4e844_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_4e844_row0_col1" class="data row0 col1" >8862</td>
#     </tr>
#     <tr>
#       <th id="T_4e844_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4e844_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_4e844_row1_col1" class="data row1 col1" >loan_status_bin</td>
#     </tr>
#     <tr>
#       <th id="T_4e844_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_be43e_ th {
#   text-align: left;
# }
# ...
