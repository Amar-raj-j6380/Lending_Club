# %%
import pandas as pd
import seaborn as sns
sns.set()
import missingno as msnum

# %%
pd.set_option("display.max_columns", 200)
pd.set_option("display.max_row", 160)
pd.set_option('max_colwidth', 200)

# %%
rejected = pd.read_csv('../../Data/Rejected_No_Null.csv')

# %%
rejected.isnull().sum()
# Out:
# Risk_Score           0
# DI                   0
# Loan Type            0
# Employment Length    0
# Accepted             0
# dtype: int64

# %%
msnum.bar(rejected);

# %%
rejected
# Out:
#          Risk_Score      DI                         Loan Type  \
# 0             693.0  0.1000  Wedding Covered but No Honeymoon
# 1             703.0  0.1000                Consolidating Debt
# 2             715.0  0.1000       Want to consolidate my debt
# 3             698.0  0.3864                           waksman
# 4             509.0  0.0943                            mdrigo
# ...             ...     ...                               ...
# 27648736      590.0  0.4126                Debt Consolidation
# 27648737       None  0.0148             Moving And Relocation
# 27648738      686.0  0.1026                             Other
# 27648739       None  0.1771                Debt Consolidation
# 27648740      684.0  0.1058                     Business Loan
#
#          Employment Length  Accepted
# 0                  4 years         0
# 1                 < 1 year         0
# 2                   1 year         0
# 3                 < 1 year         0
# 4                 < 1 year         0
# ...                    ...       ...
# 27648736          < 1 year         0
# 27648737           5 years         0
# 27648738          < 1 year         0
# 27648739          < 1 year         0
# 27648740          < 1 year         0
#
# [27648741 rows x 5 columns]

# %%
rejected.dtypes
# Out:
# Risk_Score            object
# DI                   float64
# Loan Type             object
# Employment Length     object
# Accepted               int64
# dtype: object

# %%
accepted = pd.read_csv('../../Data/Accepted_No_Null.csv')

# %%
accepted
# Out:
#          Risk_Score        DI           Loan Type Employment Length  Accepted
# 0             677.0  0.065455  Debt Consolidation         10+ years         1
# 1             717.0  0.380000       Business Loan         10+ years         1
# 2             697.0  0.317460    Home Improvement         10+ years         1
# 3             787.0  0.318182  Debt Consolidation         10+ years         1
# 4             697.0  0.099585      Major Purchase           3 years         1
# ...             ...       ...                 ...               ...       ...
# 2260659       667.0  0.252632    Home Improvement           7 years         1
# 2260660       697.0  0.222222  Debt Consolidation         10+ years         1
# 2260661       707.0  0.176211  Debt Consolidation           9 years         1
# 2260662       662.0  0.218182  Debt Consolidation           6 years         1
# 2260663       662.0  0.147368  Debt Consolidation         10+ years         1
#
# [2260664 rows x 5 columns]

# %%
accepted.isnull().sum()
# Out:
# Risk_Score           0
# DI                   0
# Loan Type            0
# Employment Length    0
# Accepted             0
# dtype: int64

# %%
accepted.dtypes
# Out:
# Risk_Score           float64
# DI                   float64
# Loan Type             object
# Employment Length     object
# Accepted               int64
# dtype: object

# %%
combo = pd.concat([accepted,rejected]).reset_index(drop=True)
combo
# Out:
#          Risk_Score        DI              Loan Type Employment Length  \
# 0             677.0  0.065455     Debt Consolidation         10+ years
# 1             717.0  0.380000          Business Loan         10+ years
# 2             697.0  0.317460       Home Improvement         10+ years
# 3             787.0  0.318182     Debt Consolidation         10+ years
# 4             697.0  0.099585         Major Purchase           3 years
# ...             ...       ...                    ...               ...
# 29909400      590.0  0.412600     Debt Consolidation          < 1 year
# 29909401       None  0.014800  Moving And Relocation           5 years
# 29909402      686.0  0.102600                  Other          < 1 year
# 29909403       None  0.177100     Debt Consolidation          < 1 year
# 29909404      684.0  0.105800          Business Loan          < 1 year
#
#           Accepted
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# ...            ...
# 29909400         0
# 29909401         0
# 29909402         0
# 29909403         0
# 29909404         0
#
# [29909405 rows x 5 columns]

# %%
combo.dtypes
# Out:
# Risk_Score            object
# DI                   float64
# Loan Type             object
# Employment Length     object
# Accepted               int64
# dtype: object

# %%
combo.describe()
# Out:
#                  DI      Accepted
# count  2.990940e+07  2.990940e+07
# mean            inf  7.558372e-02
# std             NaN  2.643309e-01
# min   -1.000000e-02  0.000000e+00
# 25%    8.571429e-02  0.000000e+00
# 50%    2.000000e-01  0.000000e+00
# 75%    3.584000e-01  0.000000e+00
# max             inf  1.000000e+00

# %%
sns.histplot(data=combo, x='Accepted');

# %%
combo['Loan Type'].value_counts(dropna=False).nlargest(20)
# Out:
# Debt Consolidation         13606950
# Other                       4856728
# Credit Card Refinancing     4183182
# Home Improvement            1341958
# Car Financing               1313994
# Major Purchase              1007934
# Business Loan                885461
# Medical Expenses             775643
# Moving And Relocation        716407
# Home Purchase                692149
# Vacation                     324714
# Green Loan                    58256
# Wedding                       20849
# Personal Loan                  6164
# Student Loan                   5728
# None                           1305
# Freedom                         492
# Motorcycle Loan                 300
# debt loan                       133
# debt free                       132
# Name: Loan Type, dtype: int64

# %%
few = combo.groupby('Accepted', group_keys=False).apply(lambda x: x.sample(frac=0.001))

# %%
few.describe()
# Out:
#                  DI      Accepted
# count  2.991000e+04  29910.000000
# mean            inf      0.075593
# std             NaN      0.264351
# min   -1.000000e-02      0.000000
# 25%    8.440000e-02      0.000000
# 50%    1.987500e-01      0.000000
# 75%    3.587750e-01      0.000000
# max             inf      1.000000

# %%
sns.histplot(data=few, x='Accepted');

# %%
few.isna().sum()
# Out:
# Risk_Score           0
# DI                   0
# Loan Type            0
# Employment Length    0
# Accepted             0
# dtype: int64

# %%
from pycaret.classification import *

# %%
experiment = setup(data = few, target = 'Accepted', categorical_features = ['Employment Length', 'Loan Type'])
# Out:
# <style type="text/css">
# #T_1e89f_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1e89f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1e89f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1e89f_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_1e89f_row0_col1" class="data row0 col1" >1047</td>
#     </tr>
#     <tr>
#       <th id="T_1e89f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1e89f_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_1e89f_row1_col1" class="data row1 col1" >Accepted</td>
#     </tr>
#     <tr>
#       <th id="T_1e89f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1e89f_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_1e89f_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_1e89f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1e89f_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_1e89f_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1e89f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1e89f_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_1e89f_row4_col1" class="data row4 col1" >(29910, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_1e89f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1e89f_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_1e89f_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1e89f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1e89f_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_1e89f_row6_col1" class="data row6 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_1e89f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1e89f_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_1e89f_row7_col1" class="data row7 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_1e89f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1e89f_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_1e89f_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1e89f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1e89f_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_1e89f_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1e89f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_1e89f_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_1e89f_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1e89f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_1e89f_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_1e89f_row11_col1" class="data row11 col1" >(20936, 527)</td>
#     </tr>
#     <tr>
#       <th id="T_1e89f_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_1e89f_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_1e89f_row12_col1" class="data row12 col1" >(8974, 527)</td>
#     </tr>
#     <tr>
#       <th id="T_1e89f_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_1e89f_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_1e89f_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_1e89f_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_1e89f_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_1e89f_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1e89f_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_1e89f_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_1e89f_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_1e89f_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_1e89f_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_1e89f_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_1e89f_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_1e89f_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_1e89f_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_1e89f_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_1e89f_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_1e89f_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1e89f_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_1e89f_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_1e89f_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1e89f_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_1e89f_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_1e89f_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_1e89f_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_1e89f_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_1e89f_row21_col1" class="data row21 col1" >0c33</td>
#     </tr>
#     <tr>
#       <th id="T_1e89f_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_1e89f_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_1e89f_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_1e89f_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_1e89f_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_1e89f_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1e89f_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_1e89f_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_1e89f_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_1e89f_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_1e89f_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_1e89f_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1e89f_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_1e89f_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_1e89f_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_1e89f_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_1e89f_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_1e89f_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1e89f_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_1e89f_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_1e89f_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_1e89f_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_1e89f_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_1e89f_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1e89f_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_1e89f_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_1e89f_row30_col1" class="data row30 col1" >None</td>
#     </tr>
#     <

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_b9de4_ th {
#   text-align: left;
# }
# #T_b9de4_row0_col0, #T_b9de4_row0_col2, #T_b9de4_row0_col3, #T_b9de4_row0_col5, #T_b9de4_row0_col6, #T_b9de4_row1_col0, #T_b9de4_row1_col1, #T_b9de4_row1_col3, #T_b9de4_row1_col4, #T_b9de4_row1_col7, #T_b9de4_row2_col0, #T_b9de4_row2_col1, #T_b9de4_row2_col2, #T_b9de4_row2_col3, #T_b9de4_row2_col4, #T_b9de4_row2_col5, #T_b9de4_row2_col6, #T_b9de4_row2_col7, #T_b9de4_row3_col0, #T_b9de4_row3_col1, #T_b9de4_row3_col2, #T_b9de4_row3_col3, #T_b9de4_row3_col4, #T_b9de4_row3_col5, #T_b9de4_row3_col6, #T_b9de4_row3_col7, #T_b9de4_row4_col0, #T_b9de4_row4_col1, #T_b9de4_row4_col2, #T_b9de4_row4_col3, #T_b9de4_row4_col4, #T_b9de4_row4_col5, #T_b9de4_row4_col6, #T_b9de4_row4_col7, #T_b9de4_row5_col0, #T_b9de4_row5_col1, #T_b9de4_row5_col2, #T_b9de4_row5_col3, #T_b9de4_row5_col4, #T_b9de4_row5_col5, #T_b9de4_row5_col6, #T_b9de4_row5_col7, #T_b9de4_row6_col0, #T_b9de4_row6_col1, #T_b9de4_row6_col2, #T_b9de4_row6_col3, #T_b9de4_row6_col4, #T_b9de4_row6_col5, #T_b9de4_row6_col6, #T_b9de4_row6_col7, #T_b9de4_row7_col0, #T_b9de4_row7_col1, #T_b9de4_row7_col2, #T_b9de4_row7_col3, #T_b9de4_row7_col4, #T_b9de4_row7_col5, #T_b9de4_row7_col6, #T_b9de4_row7_col7, #T_b9de4_row8_col0, #T_b9de4_row8_col1, #T_b9de4_row8_col2, #T_b9de4_row8_col3, #T_b9de4_row8_col4, #T_b9de4_row8_col5, #T_b9de4_row8_col6, #T_b9de4_row8_col7, #T_b9de4_row9_col0, #T_b9de4_row9_col1, #T_b9de4_row9_col2, #T_b9de4_row9_col3, #T_b9de4_row9_col4, #T_b9de4_row9_col5, #T_b9de4_row9_col6, #T_b9de4_row9_col7, #T_b9de4_row10_col0, #T_b9de4_row10_col1, #T_b9de4_row10_col2, #T_b9de4_row10_col4, #T_b9de4_row10_col5, #T_b9de4_row10_col6, #T_b9de4_row10_col7, #T_b9de4_row11_col0, #T_b9de4_row11_col1, #T_b9de4_row11_col2, #T_b9de4_row11_col3, #T_b9de4_row11_col4, #T_b9de4_row11_col5, #T_b9de4_row11_col6, #T_b9de4_row11_col7, #T_b9de4_row12_col0, #T_b9de4_row12_col1, #T_b9de4_row12_col2, #T_b9de4_row12_col3, #T_b9de4_row12_col4, #T_b9de4_row12_col5, #T_b9de4_row12_col6, #T_b9de4_row12_col7, #T_b9de4_row13_col0, #T_b9de4_row13_col1, #T_b9de4_row13_col2, #T_b9de4_row13_col3, #T_b9de4_row13_col4, #T_b9de4_row13_col5, #T_b9de4_row13_col6, #T_b9de4_row13_col7, #T_b9de4_row14_col0, #T_b9de4_row14_col1, #T_b9de4_row14_col2, #T_b9de4_row14_col3, #T_b9de4_row14_col4, #T_b9de4_row14_col5, #T_b9de4_row14_col6, #T_b9de4_row14_col7 {
#   text-align: left;
# }
# #T_b9de4_row0_col1, #T_b9de4_row0_col4, #T_b9de4_row0_col7, #T_b9de4_row1_col2, #T_b9de4_row1_col5, #T_b9de4_row1_col6, #T_b9de4_row10_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_b9de4_row0_col8, #T_b9de4_row1_col8, #T_b9de4_row2_col8, #T_b9de4_row3_col8, #T_b9de4_row4_col8, #T_b9de4_row5_col8, #T_b9de4_row6_col8, #T_b9de4_row7_col8, #T_b9de4_row8_col8, #T_b9de4_row9_col8, #T_b9de4_row10_col8, #T_b9de4_row11_col8, #T_b9de4_row12_col8, #T_b9de4_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_b9de4_row14_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_b9de4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9de4_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_b9de4_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_b9de4_row0_col1" class="data row0 col1" >0.9899</td>
#       <td id="T_b9de4_row0_col2" class="data row0 col2" >0.9976</td>
#       <td id="T_b9de4_row0_col3" class="data row0 col3" >0.9086</td>
#       <td id="T_b9de4_row0_col4" class="data row0 col4" >0.9562</td>
#       <td id="T_b9de4_row0_col5" class="data row0 col5" >0.9317</td>
#       <td id="T_b9de4_row0_col6" class="data row0 col6" >0.9263</td>
#       <td id="T_b9de4_row0_col7" class="data row0 col7" >0.9267</td>
#       <td id="T_b9de4_row0_col8" class="data row0 col8" >0.5410</td>
#     </tr>
#     <tr>
#       <th id="T_b9de4_level0_row1" class="row_heading level0 row1" >catboost</th>
#       <td id="T_b9de4_row1_col0" class="data row1 col0" >CatBoost Classifier</td>
#       <td id="T_b9de4_row1_col1" class="data row1 col1" >0.9898</td>
#       <td id="T_b9de4_row1_col2" class="data row1 col2" >0.9977</td>
#       <td id="T_b9de4_row1_col3" class="data row1 col3" >0.9206</td>
#       <td id="T_b9de4_row1_col4" class="data row1 col4" >0.9437</td>
#       <td id="T_b9de4_row1_col5" class="data row1 col5" >0.9319</td>
#       <td id="T_b9de4_row1_col6" class="data row1 col6" >0.9264</td>
#       <td id="T_b9de4_row1_col7" class="data row1 col7" >0.9266</td>
#       <td id="T_b9de4_row1_col8" class="data row1 col8" >1.2730</td>
#     </tr>
#     <tr>
#       <th id="T_b9de4_level0_row2" class="row_heading level0 row2" >ada</th>
#       <td id="T_b9de4_row2_col0" class="data row2 col0" >Ada Boost Classifier</td>
#       <td id="T_b9de4_row2_col1" class="data row2 col1" >0.9882</td>
#       <td id="T_b9de4_row2_col2" class="data row2 col2" >0.9969</td>
#       <td id="T_b9de4_row2_col3" class="data row2 col3" >0.8879</td>
#       <td id="T_b9de4_row2_col4" class="data row2 col4" >0.9532</td>
#       <td id="T_b9de4_row2_col5" class="data row2 col5" >0.9193</td>
#       <td id="T_b9de4_row2_col6" class="data row2 col6" >0.9130</td>
#       <td id="T_b9de4_row2_col7" class="data row2 col7" >0.9137</td>
#       <td id="T_b9de4_row2_col8" class="data row2 col8" >0.4640</td>
#     </tr>
#     <tr>
#       <th id="T_b9de4_level0_row3" class="row_heading level0 row3" >gbc</th>
#       <td id="T_b9de4_row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#       <td id="T_b9de4_row3_col1" class="data row3 col1" >0.9865</td>
#       <td id="T_b9de4_row3_col2" class="data row3 col2" >0.9943</td>
#       <td id="T_b9de4_row3_col3" class="data row3 col3" >0.8651</td>
#       <td id="T_b9de4_row3_col4" class="data row3 col4" >0.9522</td>
#       <td id="T_b9de4_row3_col5" class="data row3 col5" >0.9064</td>
#       <td id="T_b9de4_row3_col6" class="data row3 col6" >0.8992</td>
#       <td id="T_b9de4_row3_col7" class="data row3 col7" >0.9005</td>
#       <td id="T_b9de4_row3_col8" class="data row3 col8" >1.7110</td>
#     </tr>
#     <tr>
#       <th id="T_b9de4_level0_row4" class="row_heading level0 row4" >svm</th>
#       <td id="T_b9de4_row4_col0" class="data row4 col0" >SVM - Linear Kernel</td>
#       <td id="T_b9de4_row4_col1" class="data row4 col1" >0.9855</td>
#       <td id="T_b9de4_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_b9de4_row4_col3" class="data row4 col3" >0.8778</td>
#       <td id="T_b9de4_row4_col4" class="data row4 col4" >0.9267</td>
#       <td id="T_b9de4_row4_col5" class="data row4 col5" >0.9013</td>
#       <td id="T_b9de4_row4_col6" class="data row4 col6" >0.8935</td>
#       <td id="T_b9de4_row4_col7" class="data row4 col7" >0.8941</td>
#       <td id="T_b9de4_row4_col8" class="data row4 col8" >0.1090</td>
#     </tr>
#     <tr>
#       <th id="T_b9de4_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_b9de4_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_b9de4_row5_col1" class="data row5 col1" >0.9848</td>
#       <td id="T_b9de4_row5_col2" class="data row5 col2" >0.9960</td>
#       <td id="T_b9de4_row5_col3" class="data row5 col3" >0.8683</td>
#       <td id="T_b9de4_row5_col4" class="data row5 col4" >0.9258</td>
#       <td id="T_b9de4_row5_col5" class="data row5 col5" >0.8959</td>
#       <td id="T_b9de4_row5_col6" class="data row5 col6" >0.8877</td>
#       <td id="T_b9de4_row5_col7" class="data row5 col7" >0.8884</td>
#       <td id="T_b9de4_row5_col8" class="d

# %%
print(best_model)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=1047, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# xgboost         Extreme Gradient Boosting
# lightgbm  Light Gradient Boosting Machine
# catboost              CatBoost Classifier
# dummy                    Dummy Classifier
#
#                                                   Reference  Turbo
# ID
# lr        sklearn.linear_model._logistic.LogisticRegression   True
# knn       sklearn.neighbors._classification.KNeighborsCl...   True
# nb                           sklearn.naive_bayes.GaussianNB   True
# dt             sklearn.tree._classes.DecisionTreeClassifier   True
# svm       sklearn.linear_model._stochastic_gradient.SGDC...   True
# rbfsvm                             sklearn.svm._classes.SVC  False
# gpc       sklearn.gaussian_process._gpc.GaussianProcessC...  False
# mlp       sklearn.neural_network._multilayer_perceptron....  False
# ridge           sklearn.linear_model._ridge.RidgeClassifier   True
# rf          sklearn.ensemble._forest.RandomForestClassifier   True
# qda       sklearn.discriminant_analysis.QuadraticDiscrim...   True
# ada       sklearn.ensemble._weight_boosting.AdaBoostClas...   True
# gbc         sklearn.ensemble._gb.GradientBoostingClassifier   True
# lda       sklearn.discriminant_analysis.LinearDiscrimina...   True
# et            sklearn.ensemble._forest.ExtraTreesClassifier   True
# xgboost                       xgboost.sklearn.XGBClassifier   True
# lightgbm                    lightgbm.sklearn.LGBMClassifier   True
# catboost                   catboost.core.CatBoostClassifier   True
# dummy                         sklearn.dummy.DummyClassifier   True

# %%
lr = create_model('lr')
# Out:
# <style type="text/css">
# #T_67377_row10_col0, #T_67377_row10_col1, #T_67377_row10_col2, #T_67377_row10_col3, #T_67377_row10_col4, #T_67377_row10_col5, #T_67377_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_67377_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_67377_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_67377_row0_col0" class="data row0 col0" >0.9938</td>
#       <td id="T_67377_row0_col1" class="data row0 col1" >0.9985</td>
#       <td id="T_67377_row0_col2" class="data row0 col2" >0.9308</td>
#       <td id="T_67377_row0_col3" class="data row0 col3" >0.9867</td>
#       <td id="T_67377_row0_col4" class="data row0 col4" >0.9579</td>
#       <td id="T_67377_row0_col5" class="data row0 col5" >0.9546</td>
#       <td id="T_67377_row0_col6" class="data row0 col6" >0.9551</td>
#     </tr>
#     <tr>
#       <th id="T_67377_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_67377_row1_col0" class="data row1 col0" >0.9909</td>
#       <td id="T_67377_row1_col1" class="data row1 col1" >0.9980</td>
#       <td id="T_67377_row1_col2" class="data row1 col2" >0.9182</td>
#       <td id="T_67377_row1_col3" class="data row1 col3" >0.9605</td>
#       <td id="T_67377_row1_col4" class="data row1 col4" >0.9389</td>
#       <td id="T_67377_row1_col5" class="data row1 col5" >0.9340</td>
#       <td id="T_67377_row1_col6" class="data row1 col6" >0.9343</td>
#     </tr>
#     <tr>
#       <th id="T_67377_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_67377_row2_col0" class="data row2 col0" >0.9862</td>
#       <td id="T_67377_row2_col1" class="data row2 col1" >0.9961</td>
#       <td id="T_67377_row2_col2" class="data row2 col2" >0.8805</td>
#       <td id="T_67377_row2_col3" class="data row2 col3" >0.9333</td>
#       <td id="T_67377_row2_col4" class="data row2 col4" >0.9061</td>
#       <td id="T_67377_row2_col5" class="data row2 col5" >0.8987</td>
#       <td id="T_67377_row2_col6" class="data row2 col6" >0.8991</td>
#     </tr>
#     <tr>
#       <th id="T_67377_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_67377_row3_col0" class="data row3 col0" >0.9885</td>
#       <td id="T_67377_row3_col1" class="data row3 col1" >0.9977</td>
#       <td id="T_67377_row3_col2" class="data row3 col2" >0.8931</td>
#       <td id="T_67377_row3_col3" class="data row3 col3" >0.9530</td>
#       <td id="T_67377_row3_col4" class="data row3 col4" >0.9221</td>
#       <td id="T_67377_row3_col5" class="data row3 col5" >0.9159</td>
#       <td id="T_67377_row3_col6" class="data row3 col6" >0.9165</td>
#     </tr>
#     <tr>
#       <th id="T_67377_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_67377_row4_col0" class="data row4 col0" >0.9943</td>
#       <td id="T_67377_row4_col1" class="data row4 col1" >0.9986</td>
#       <td id="T_67377_row4_col2" class="data row4 col2" >0.9434</td>
#       <td id="T_67377_row4_col3" class="data row4 col3" >0.9804</td>
#       <td id="T_67377_row4_col4" class="data row4 col4" >0.9615</td>
#       <td id="T_67377_row4_col5" class="data row4 col5" >0.9584</td>
#       <td id="T_67377_row4_col6" class="data row4 col6" >0.9587</td>
#     </tr>
#     <tr>
#       <th id="T_67377_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_67377_row5_col0" class="data row5 col0" >0.9890</td>
#       <td id="T_67377_row5_col1" class="data row5 col1" >0.9971</td>
#       <td id="T_67377_row5_col2" class="data row5 col2" >0.9119</td>
#       <td id="T_67377_row5_col3" class="data row5 col3" >0.9416</td>
#       <td id="T_67377_row5_col4" class="data row5 col4" >0.9265</td>
#       <td id="T_67377_row5_col5" class="data row5 col5" >0.9206</td>
#       <td id="T_67377_row5_col6" class="data row5 col6" >0.9207</td>
#     </tr>
#     <tr>
#       <th id="T_67377_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_67377_row6_col0" class="data row6 col0" >0.9881</td>
#       <td id="T_67377_row6_col1" class="data row6 col1" >0.9970</td>
#       <td id="T_67377_row6_col2" class="data row6 col2" >0.9051</td>
#       <td id="T_67377_row6_col3" class="data row6 col3" >0.9346</td>
#       <td id="T_67377_row6_col4" class="data row6 col4" >0.9196</td>
#       <td id="T_67377_row6_col5" class="data row6 col5" >0.9132</td>
#       <td id="T_67377_row6_col6" class="data row6 col6" >0.9133</td>
#     </tr>
#     <tr>
#       <th id="T_67377_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_67377_row7_col0" class="data row7 col0" >0.9904</td>
#       <td id="T_67377_row7_col1" class="data row7 col1" >0.9976</td>
#       <td id="T_67377_row7_col2" class="data row7 col2" >0.9177</td>
#       <td id="T_67377_row7_col3" class="data row7 col3" >0.9539</td>
#       <td id="T_67377_row7_col4" class="data row7 col4" >0.9355</td>
#       <td id="T_67377_row7_col5" class="data row7 col5" >0.9303</td>
#       <td id="T_67377_row7_col6" class="data row7 col6" >0.9305</td>
#     </tr>
#     <tr>
#       <th id="T_67377_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_67377_row8_col0" class="data row8 col0" >0.9933</td>
#       <td id="T_67377_row8_col1" class="data row8 col1" >0.9985</td>
#       <td id="T_67377_row8_col2" class="data row8 col2" >0.9304</td>
#       <td id="T_67377_row8_col3" class="data row8 col3" >0.9800</td>
#       <td id="T_67377_row8_col4" class="data row8 col4" >0.9545</td>
#       <td id="T_67377_row8_col5" class="data row8 col5" >0.9509</td>
#       <td id="T_67377_row8_col6" class="data row8 col6" >0.9513</td>
#     </tr>
#     <tr>
#       <th id="T_67377_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_67377_row9_col0" class="data row9 col0" >0.9847</td>
#       <td id="T_67377_row9_col1" class="data row9 col1" >0.9966</td>
#       <td id="T_67377_row9_col2" class="data row9 col2" >0.8553</td>
#       <td id="T_67377_row9_col3" class="data row9 col3" >0.9379</td>
#       <td id="T_67377_row9_col4" class="data row9 col4" >0.8947</td>
#       <td id="T_67377_row9_col5" class="data row9 col5" >0.8865</td>
#       <td id="T_67377_row9_col6" class="data row9 col6" >0.8876</td>
#     </tr>
#     <tr>
#       <th id="T_67377_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_67377_row10_col0" class="data row10 col0" >0.9899</td>
#       <td id="T_67377_row10_col1" class="data row10 col1" >0.9976</td>
#       <td id="T_67377_row10_col2" class="data row10 col2" >0.9086</td>
#       <td id="T_67377_row10_col3" class="data row10 col3" >0.9562</td>
#       <td id="T_67377_row10_col4" class="data row10 col4" >0.9317</td>
#       <td id="T_67377_row10_col5" class="data row10 col5" >0.9263</td>
#       <td id="T_67377_row10_col6" class="data row10 col6" >0.9267</td>
#     </tr>
#     <tr>
#       <th id="T_67377_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_67377_row11_col0" class="data row11 col0" >0.0031</td>
#       <td id="T_67377_row11_col1" class="data row11 col1" >0.0008</td>
#       <td id="T_67377_row11_col2" class="data row11 col2" >0.0250</td>
#       <td id="T_67377_row11_col3" class="data row11 col3" >0.0191</td>
#       <td id="T_67377_row11_col4" class="data row11 col4" >0.0211</td>
#       <td id="T_67377_row11_col5" class="data row11 col5" >0.0227</td>
#       <td id="T_67377_row11_col6" class="data row11 col6" >0.022

# %%
print(lr)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=1047, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
plot_model(lr, plot='auc')

# %%
plot_model(lr, plot='confusion_matrix')

# %%
plot_model(lr, plot='feature')

# %%
cb = create_model('catboost')
# Out:
# <style type="text/css">
# #T_6f3be_row10_col0, #T_6f3be_row10_col1, #T_6f3be_row10_col2, #T_6f3be_row10_col3, #T_6f3be_row10_col4, #T_6f3be_row10_col5, #T_6f3be_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_6f3be_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f3be_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6f3be_row0_col0" class="data row0 col0" >0.9938</td>
#       <td id="T_6f3be_row0_col1" class="data row0 col1" >0.9989</td>
#       <td id="T_6f3be_row0_col2" class="data row0 col2" >0.9497</td>
#       <td id="T_6f3be_row0_col3" class="data row0 col3" >0.9679</td>
#       <td id="T_6f3be_row0_col4" class="data row0 col4" >0.9587</td>
#       <td id="T_6f3be_row0_col5" class="data row0 col5" >0.9554</td>
#       <td id="T_6f3be_row0_col6" class="data row0 col6" >0.9554</td>
#     </tr>
#     <tr>
#       <th id="T_6f3be_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6f3be_row1_col0" class="data row1 col0" >0.9914</td>
#       <td id="T_6f3be_row1_col1" class="data row1 col1" >0.9983</td>
#       <td id="T_6f3be_row1_col2" class="data row1 col2" >0.9434</td>
#       <td id="T_6f3be_row1_col3" class="data row1 col3" >0.9434</td>
#       <td id="T_6f3be_row1_col4" class="data row1 col4" >0.9434</td>
#       <td id="T_6f3be_row1_col5" class="data row1 col5" >0.9387</td>
#       <td id="T_6f3be_row1_col6" class="data row1 col6" >0.9387</td>
#     </tr>
#     <tr>
#       <th id="T_6f3be_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6f3be_row2_col0" class="data row2 col0" >0.9871</td>
#       <td id="T_6f3be_row2_col1" class="data row2 col1" >0.9959</td>
#       <td id="T_6f3be_row2_col2" class="data row2 col2" >0.8931</td>
#       <td id="T_6f3be_row2_col3" class="data row2 col3" >0.9342</td>
#       <td id="T_6f3be_row2_col4" class="data row2 col4" >0.9132</td>
#       <td id="T_6f3be_row2_col5" class="data row2 col5" >0.9062</td>
#       <td id="T_6f3be_row2_col6" class="data row2 col6" >0.9065</td>
#     </tr>
#     <tr>
#       <th id="T_6f3be_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6f3be_row3_col0" class="data row3 col0" >0.9881</td>
#       <td id="T_6f3be_row3_col1" class="data row3 col1" >0.9977</td>
#       <td id="T_6f3be_row3_col2" class="data row3 col2" >0.8994</td>
#       <td id="T_6f3be_row3_col3" class="data row3 col3" >0.9408</td>
#       <td id="T_6f3be_row3_col4" class="data row3 col4" >0.9196</td>
#       <td id="T_6f3be_row3_col5" class="data row3 col5" >0.9132</td>
#       <td id="T_6f3be_row3_col6" class="data row3 col6" >0.9134</td>
#     </tr>
#     <tr>
#       <th id="T_6f3be_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6f3be_row4_col0" class="data row4 col0" >0.9933</td>
#       <td id="T_6f3be_row4_col1" class="data row4 col1" >0.9989</td>
#       <td id="T_6f3be_row4_col2" class="data row4 col2" >0.9497</td>
#       <td id="T_6f3be_row4_col3" class="data row4 col3" >0.9618</td>
#       <td id="T_6f3be_row4_col4" class="data row4 col4" >0.9557</td>
#       <td id="T_6f3be_row4_col5" class="data row4 col5" >0.9521</td>
#       <td id="T_6f3be_row4_col6" class="data row4 col6" >0.9521</td>
#     </tr>
#     <tr>
#       <th id="T_6f3be_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6f3be_row5_col0" class="data row5 col0" >0.9895</td>
#       <td id="T_6f3be_row5_col1" class="data row5 col1" >0.9972</td>
#       <td id="T_6f3be_row5_col2" class="data row5 col2" >0.9245</td>
#       <td id="T_6f3be_row5_col3" class="data row5 col3" >0.9363</td>
#       <td id="T_6f3be_row5_col4" class="data row5 col4" >0.9304</td>
#       <td id="T_6f3be_row5_col5" class="data row5 col5" >0.9247</td>
#       <td id="T_6f3be_row5_col6" class="data row5 col6" >0.9247</td>
#     </tr>
#     <tr>
#       <th id="T_6f3be_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6f3be_row6_col0" class="data row6 col0" >0.9895</td>
#       <td id="T_6f3be_row6_col1" class="data row6 col1" >0.9971</td>
#       <td id="T_6f3be_row6_col2" class="data row6 col2" >0.9177</td>
#       <td id="T_6f3be_row6_col3" class="data row6 col3" >0.9416</td>
#       <td id="T_6f3be_row6_col4" class="data row6 col4" >0.9295</td>
#       <td id="T_6f3be_row6_col5" class="data row6 col5" >0.9238</td>
#       <td id="T_6f3be_row6_col6" class="data row6 col6" >0.9239</td>
#     </tr>
#     <tr>
#       <th id="T_6f3be_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6f3be_row7_col0" class="data row7 col0" >0.9895</td>
#       <td id="T_6f3be_row7_col1" class="data row7 col1" >0.9972</td>
#       <td id="T_6f3be_row7_col2" class="data row7 col2" >0.9177</td>
#       <td id="T_6f3be_row7_col3" class="data row7 col3" >0.9416</td>
#       <td id="T_6f3be_row7_col4" class="data row7 col4" >0.9295</td>
#       <td id="T_6f3be_row7_col5" class="data row7 col5" >0.9238</td>
#       <td id="T_6f3be_row7_col6" class="data row7 col6" >0.9239</td>
#     </tr>
#     <tr>
#       <th id="T_6f3be_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6f3be_row8_col0" class="data row8 col0" >0.9904</td>
#       <td id="T_6f3be_row8_col1" class="data row8 col1" >0.9983</td>
#       <td id="T_6f3be_row8_col2" class="data row8 col2" >0.9367</td>
#       <td id="T_6f3be_row8_col3" class="data row8 col3" >0.9367</td>
#       <td id="T_6f3be_row8_col4" class="data row8 col4" >0.9367</td>
#       <td id="T_6f3be_row8_col5" class="data row8 col5" >0.9315</td>
#       <td id="T_6f3be_row8_col6" class="data row8 col6" >0.9315</td>
#     </tr>
#     <tr>
#       <th id="T_6f3be_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6f3be_row9_col0" class="data row9 col0" >0.9857</td>
#       <td id="T_6f3be_row9_col1" class="data row9 col1" >0.9973</td>
#       <td id="T_6f3be_row9_col2" class="data row9 col2" >0.8742</td>
#       <td id="T_6f3be_row9_col3" class="data row9 col3" >0.9329</td>
#       <td id="T_6f3be_row9_col4" class="data row9 col4" >0.9026</td>
#       <td id="T_6f3be_row9_col5" class="data row9 col5" >0.8949</td>
#       <td id="T_6f3be_row9_col6" class="data row9 col6" >0.8954</td>
#     </tr>
#     <tr>
#       <th id="T_6f3be_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_6f3be_row10_col0" class="data row10 col0" >0.9898</td>
#       <td id="T_6f3be_row10_col1" class="data row10 col1" >0.9977</td>
#       <td id="T_6f3be_row10_col2" class="data row10 col2" >0.9206</td>
#       <td id="T_6f3be_row10_col3" class="data row10 col3" >0.9437</td>
#       <td id="T_6f3be_row10_col4" class="data row10 col4" >0.9319</td>
#       <td id="T_6f3be_row10_col5" class="data row10 col5" >0.9264</td>
#       <td id="T_6f3be_row10_col6" class="data row10 col6" >0.9266</td>
#     </tr>
#     <tr>
#       <th id="T_6f3be_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_6f3be_row11_col0" class="data row11 col0" >0.0024</td>
#       <td id="T_6f3be_row11_col1" class="data row11 col1" >0.0009</td>
#       <td id="T_6f3be_row11_col2" class="data row11 col2" >0.0242</td>
#       <td id="T_6f3be_row11_col3" class="data row11 col3" >0.0112</td>
#       <td id="T_6f3be_row11_col4" class="data row11 col4" >0.0168</td>
#       <td id="T_6f3be_row11_col5" class="data row11 col5" >0.0181</td>
#       <td id="T_6f3be_row11_col6" class="data row11 col6" >0.017

# %%
print(cb)
# Out:
# <catboost.core.CatBoostClassifier object at 0x7f962cb6b220>

# %%
plot_model(cb, plot='auc')

# %%
plot_model(cb, plot='confusion_matrix')

# %%
plot_model(cb, plot='feature')

# %%
##Policy Code is internal way of assigning reject/accept/danger (0, 1, 2). 
##It's not available at time of application.

# %%
#State and Zip Code have no importance.

# %%
#Really not sure what "Application Date_is_month_start_1". It might just be the category 
#assigned to all Dates (all dates have a first month), and thereby not providing much informational value.
