# %%
import pandas as pd
import seaborn as sns
sns.set()
#import missingno as msnum

# %%
pd.set_option("display.max_columns", 200)
pd.set_option("display.max_row", 160)
pd.set_option('max_colwidth', 200)

# %%
accepted = pd.read_csv('../../Data/accepted.csv')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (0,19,49,59,118,129,130,131,134,135,136,139,145,146,147) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
accepted.head(3)
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  68407277        NaN     3600.0       3600.0           3600.0   36 months
# 1  68355089        NaN    24700.0      24700.0          24700.0   36 months
# 2  68341763        NaN    20000.0      20000.0          20000.0   60 months
#
#    int_rate  installment grade sub_grade     emp_title emp_length  \
# 0     13.99       123.03     C        C4       leadman  10+ years
# 1     11.99       820.28     C        C1      Engineer  10+ years
# 2     10.78       432.66     B        B4  truck driver  10+ years
#
#   home_ownership  annual_inc verification_status   issue_d loan_status  \
# 0       MORTGAGE     55000.0        Not Verified  Dec-2015  Fully Paid
# 1       MORTGAGE     65000.0        Not Verified  Dec-2015  Fully Paid
# 2       MORTGAGE     63000.0        Not Verified  Dec-2015  Fully Paid
#
#   pymnt_plan  \
# 0          n
# 1          n
# 2          n
#
# ...

# %%
pd.read_excel('../../Data/LCDataDictionary.xlsx')
# Out:
#                                     LoanStatNew  \
# 0                                acc_now_delinq
# 1                          acc_open_past_24mths
# 2                                    addr_state
# 3                                      all_util
# 4                                    annual_inc
# 5                              annual_inc_joint
# 6                              application_type
# 7                                   avg_cur_bal
# 8                                bc_open_to_buy
# 9                                       bc_util
# 10                     chargeoff_within_12_mths
# 11                      collection_recovery_fee
# 12                   collections_12_mths_ex_med
# 13                                  delinq_2yrs
# 14                                  delinq_amnt
# 15                                         desc
# 16                                          dti
# 17                                    dti_joint
# ...

# %%
#accepted.isnull().sum()

# %%
accepted.shape
# Out:
# (2260701, 151)

# %%
accepted = accepted.assign(FICO = (accepted['fico_range_low'] + accepted['fico_range_high'])/2)

# %%
Risk = accepted[['issue_d','FICO', 'grade', 'emp_length']]

# %%
Risk = Risk.assign(Date = pd.to_datetime(Risk.issue_d))
Risk
# Out:
#           issue_d   FICO grade emp_length       Date
# 0        Dec-2015  677.0     C  10+ years 2015-12-01
# 1        Dec-2015  717.0     C  10+ years 2015-12-01
# 2        Dec-2015  697.0     B  10+ years 2015-12-01
# 3        Dec-2015  787.0     C  10+ years 2015-12-01
# 4        Dec-2015  697.0     F    3 years 2015-12-01
# ...           ...    ...   ...        ...        ...
# 2260696  Oct-2016  707.0     B    9 years 2016-10-01
# 2260697  Oct-2016  662.0     C    6 years 2016-10-01
# 2260698  Oct-2016  662.0     C  10+ years 2016-10-01
# 2260699       NaN    NaN   NaN        NaN        NaT
# 2260700       NaN    NaN   NaN        NaN        NaT
#
# [2260701 rows x 5 columns]

# %%
Risk
# Out:
#           issue_d   FICO grade emp_length       Date
# 0        Dec-2015  677.0     C  10+ years 2015-12-01
# 1        Dec-2015  717.0     C  10+ years 2015-12-01
# 2        Dec-2015  697.0     B  10+ years 2015-12-01
# 3        Dec-2015  787.0     C  10+ years 2015-12-01
# 4        Dec-2015  697.0     F    3 years 2015-12-01
# ...           ...    ...   ...        ...        ...
# 2260696  Oct-2016  707.0     B    9 years 2016-10-01
# 2260697  Oct-2016  662.0     C    6 years 2016-10-01
# 2260698  Oct-2016  662.0     C  10+ years 2016-10-01
# 2260699       NaN    NaN   NaN        NaN        NaT
# 2260700       NaN    NaN   NaN        NaN        NaT
#
# [2260701 rows x 5 columns]

# %%
Risk = Risk.sort_values(by='Date')
Risk
# Out:
#           issue_d   FICO grade emp_length       Date
# 1654413  Jun-2007  742.0     A   < 1 year 2007-06-01
# 1654392  Jun-2007  697.0     C   < 1 year 2007-06-01
# 1654393  Jun-2007  697.0     B    2 years 2007-06-01
# 1654394  Jun-2007  707.0     B   < 1 year 2007-06-01
# 1654395  Jun-2007  672.0     C   < 1 year 2007-06-01
# ...           ...    ...   ...        ...        ...
# 2038502       NaN    NaN   NaN        NaN        NaT
# 2157151       NaN    NaN   NaN        NaN        NaT
# 2157152       NaN    NaN   NaN        NaN        NaT
# 2260699       NaN    NaN   NaN        NaN        NaT
# 2260700       NaN    NaN   NaN        NaN        NaT
#
# [2260701 rows x 5 columns]

# %%
sns.scatterplot(data=Risk, x='grade', y='FICO');

# %%
Low_FICO = Risk[Risk.FICO < 660]
Low_FICO['grade'].value_counts()
# Out:
# E    216
# D     99
# G     91
# F     83
# Name: grade, dtype: int64

# %%
High_FICO = Risk[Risk.FICO >= 660]
High_FICO['grade'].value_counts()
# Out:
# B    663557
# C    650053
# A    433027
# D    324325
# E    135423
# F     41717
# G     12077
# Name: grade, dtype: int64

# %%
Low_FICO
# Out:
#           issue_d   FICO grade emp_length       Date
# 1654397  Jun-2007  642.0     E  10+ years 2007-06-01
# 1654390  Jul-2007  652.0     E     1 year 2007-07-01
# 1654387  Jul-2007  657.0     D    2 years 2007-07-01
# 1654354  Jul-2007  642.0     E    2 years 2007-07-01
# 1654361  Jul-2007  652.0     F     1 year 2007-07-01
# ...           ...    ...   ...        ...        ...
# 1653300  Oct-2008  652.0     E    3 years 2008-10-01
# 1653304  Oct-2008  657.0     D     1 year 2008-10-01
# 1653309  Oct-2008  652.0     E    4 years 2008-10-01
# 1653312  Oct-2008  647.0     F   < 1 year 2008-10-01
# 1653313  Oct-2008  652.0     E    8 years 2008-10-01
#
# [489 rows x 5 columns]

# %%
Low_FICO.describe()
# Out:
#              FICO
# count  489.000000
# mean   649.269939
# std      6.809824
# min    612.000000
# 25%    647.000000
# 50%    652.000000
# 75%    657.000000
# max    657.000000

# %%
#Employment Length doesn't seem to solve it. 
#Low_FICO.emp_length.value_counts()

# %%
Low_FICO.isna().sum()
# Out:
# issue_d       0
# FICO          0
# grade         0
# emp_length    0
# Date          0
# dtype: int64

# %%
High_FICO
# Out:
#           issue_d   FICO grade emp_length       Date
# 1654413  Jun-2007  742.0     A   < 1 year 2007-06-01
# 1654392  Jun-2007  697.0     C   < 1 year 2007-06-01
# 1654393  Jun-2007  697.0     B    2 years 2007-06-01
# 1654394  Jun-2007  707.0     B   < 1 year 2007-06-01
# 1654395  Jun-2007  672.0     C   < 1 year 2007-06-01
# ...           ...    ...   ...        ...        ...
# 1379439  Dec-2018  687.0     C  10+ years 2018-12-01
# 1379438  Dec-2018  682.0     B  10+ years 2018-12-01
# 1379437  Dec-2018  692.0     C  10+ years 2018-12-01
# 1379444  Dec-2018  667.0     A    8 years 2018-12-01
# 1352691  Dec-2018  702.0     B   < 1 year 2018-12-01
#
# [2260179 rows x 5 columns]

# %%
combo = pd.read_csv('../../Data/Combo_4_DropNAs.csv')

# %%
combo
# Out:
#           Risk_Score        DI           Loan Type Employment Length  Accepted
# 0              677.0  0.065455  Debt Consolidation         10+ years         1
# 1              717.0  0.380000       Business Loan         10+ years         1
# 2              697.0  0.317460    Home Improvement         10+ years         1
# 3              787.0  0.318182  Debt Consolidation         10+ years         1
# 4              697.0  0.099585      Major Purchase           3 years         1
# ...              ...       ...                 ...               ...       ...
# 11105947       681.0  0.551500  Debt Consolidation          < 1 year         0
# 11105948       531.0  0.313100  Debt Consolidation          < 1 year         0
# 11105949       590.0  0.412600  Debt Consolidation          < 1 year         0
# 11105950       686.0  0.102600               Other          < 1 year         0
# 11105951       684.0  0.105800       Business Loan          < 1 year         0
#
# ...

# %%
band = combo[(combo.Risk_Score >= 612) & (combo.Risk_Score < 660)]
band
# Out:
#           Risk_Score        DI                Loan Type Employment Length  \
# 1541826        632.0  0.060000                    Other            1 year
# 1541946        627.0  0.051724       Debt Consolidation            1 year
# 1543572        652.0  0.129032       Debt Consolidation           3 years
# 1543576        657.0  0.016667       Debt Consolidation            1 year
# 1543581        652.0  0.083333       Debt Consolidation           4 years
# ...              ...       ...                      ...               ...
# 11105915       620.0  0.115200            Car Financing          < 1 year
# 11105921       615.0  0.186100                    Other          < 1 year
# 11105923       628.0  0.246100  Credit Card Refinancing          < 1 year
# 11105926       639.0  0.264600       Debt Consolidation          < 1 year
# 11105932       650.0  2.440200                    Other          < 1 year
#
#           Accepted
# 1541826          1
# 1541946          1
# ...

# %%
band.describe()
# Out:
#          Risk_Score            DI      Accepted
# count  2.802695e+06  2.802695e+06  2.802695e+06
# mean   6.364090e+02  1.154011e+00  1.744749e-04
# std    1.372407e+01  5.042744e+01  1.320775e-02
# min    6.120000e+02 -1.000000e-02  0.000000e+00
# 25%    6.250000e+02  1.126000e-01  0.000000e+00
# 50%    6.370000e+02  2.137000e-01  0.000000e+00
# 75%    6.480000e+02  3.552000e-01  0.000000e+00
# max    6.590000e+02  4.408800e+04  1.000000e+00

# %%
band.groupby('Accepted').describe()
# Out:
#          Risk_Score                                                            \
#               count        mean        std    min    25%    50%    75%    max
# Accepted
# 0         2802206.0  636.406777  13.723921  612.0  625.0  637.0  648.0  659.0
# 1             489.0  649.269939   6.809824  612.0  647.0  652.0  657.0  657.0
#
#                  DI                                                   \
#               count      mean        std       min     25%       50%
# Accepted
# 0         2802206.0  1.154185  50.431840 -0.010000  0.1126  0.213700
# 1             489.0  0.155994   0.115493  0.012882  0.0750  0.132394
#
#
#                75%           max
# Accepted
# 0         0.355300  44088.000000
# 1         0.202308      0.949367

# %%
from pycaret.classification import *

# %%
experiment = setup(data = band, target = 'Accepted', categorical_features = ['Employment Length', 'Loan Type'])
# Out:
# IntProgress(value=0, description='Processing: ', max=3)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            13:45:40
# Status     . . . . . . . . . . . . . . . . . .  Preprocessing Data
# Text(value="Following data types have been inferred automatically, if they are correct press enter to continue…
#                      Data Type
# Risk_Score             Numeric
# DI                     Numeric
# Loan Type          Categorical
# Employment Length  Categorical
# Accepted                 Label
